# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import yfinance as yf  
from urllib.request import urlretrieve
from datetime import datetime
import pandas as pd

# %%
ticker = 'WIG'
interval = 'd'
url = f'https://stooq.com/q/d/l/?s={ticker}&i={interval}'
csv_file = ticker + '.csv'
urlretrieve(url, csv_file)


#PKN Orlen
ticker = 'PKN'
interval = 'd'
url = f'https://stooq.com/q/d/l/?s={ticker}&i={interval}'
csv_file = ticker + '.csv'
urlretrieve(url, csv_file)
PKN = pd.read_csv(csv_file, index_col='Date', parse_dates=['Date'],
            date_parser=lambda x: datetime.strptime(x, '%Y-%m-%d'))

#KGHM
ticker = 'KGH'
interval = 'd'
url = f'https://stooq.com/q/d/l/?s={ticker}&i={interval}'
csv_file = ticker + '.csv'
urlretrieve(url, csv_file)
KGH = pd.read_csv(csv_file, index_col='Date', parse_dates=['Date'],
            date_parser=lambda x: datetime.strptime(x, '%Y-%m-%d'))


#PKO
ticker = 'PKO'
interval = 'd'
url = f'https://stooq.com/q/d/l/?s={ticker}&i={interval}'
csv_file = ticker + '.csv'
urlretrieve(url, csv_file)
PKO = pd.read_csv(csv_file, index_col='Date', parse_dates=['Date'],
            date_parser=lambda x: datetime.strptime(x, '%Y-%m-%d'))


#PEKAO
ticker = 'PEO'
interval = 'd'
url = f'https://stooq.com/q/d/l/?s={ticker}&i={interval}'
csv_file = ticker + '.csv'
urlretrieve(url, csv_file)
PEO = pd.read_csv(csv_file, index_col='Date', parse_dates=['Date'],
            date_parser=lambda x: datetime.strptime(x, '%Y-%m-%d'))

#R22
ticker = 'R22'
interval = 'd'
url = f'https://stooq.com/q/d/l/?s={ticker}&i={interval}'
csv_file = ticker + '.csv'
urlretrieve(url, csv_file)
R22 = pd.read_csv(csv_file, index_col='Date', parse_dates=['Date'],
            date_parser=lambda x: datetime.strptime(x, '%Y-%m-%d'))

#PZU
ticker = 'PZU'
interval = 'd'
url = f'https://stooq.com/q/d/l/?s={ticker}&i={interval}'
csv_file = ticker + '.csv'
urlretrieve(url, csv_file)
PZU = pd.read_csv(csv_file, index_col='Date', parse_dates=['Date'],
            date_parser=lambda x: datetime.strptime(x, '%Y-%m-%d'))

#DINO
ticker = 'DNP'
interval = 'd'
url = f'https://stooq.com/q/d/l/?s={ticker}&i={interval}'
csv_file = ticker + '.csv'
urlretrieve(url, csv_file)
DNP = pd.read_csv(csv_file, index_col='Date', parse_dates=['Date'],
            date_parser=lambda x: datetime.strptime(x, '%Y-%m-%d'))

#Torpol
ticker = 'TOR'
interval = 'd'
url = f'https://stooq.com/q/d/l/?s={ticker}&i={interval}'
csv_file = ticker + '.csv'
urlretrieve(url, csv_file)
TOR = pd.read_csv(csv_file, index_col='Date', parse_dates=['Date'],
            date_parser=lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
R22_end = R22.tail(1300)
PKN_end = PKN.tail(1300)
PEO_end = PEO.tail(1300)
PZU_end = PZU.tail(1300)
KGH_end = KGH.tail(1300)
PKO_end = PKO.tail(1300)
DNP_end = DNP.tail(1300)
TOR_end = TOR.tail(1300)

stocks = pd.concat([R22_end['Open'],PKN_end['Open'],PEO_end['Open'],PZU_end['Open'],KGH_end['Open'],PKO_end['Open'],DNP_end['Open'],TOR_end['Open']],axis=1)
stocks.columns = ['R22','PKN','PEO','PZU','KGH','PKO','DNP','TOR']

stocks
# Out:
#               R22     PKN     PEO     PZU     KGH     PKO    DNP     TOR
# Date
# 2017-01-26    NaN  70.297  109.71  27.810  121.38  30.287    NaN  10.561
# 2017-01-27    NaN  69.033  108.13  27.507  118.92  30.106    NaN  10.537
# 2017-01-30    NaN  70.592  109.20  27.499  122.86  29.667    NaN  10.466
# 2017-01-31    NaN  69.196  106.94  27.266  120.20  29.236    NaN  10.537
# 2017-02-01    NaN  69.441  107.73  27.452  123.30  29.599    NaN  10.832
# ...           ...     ...     ...     ...     ...     ...    ...     ...
# 2022-04-04  47.20  77.000  118.00  34.800  175.85  41.400  346.0  15.200
# 2022-04-05  45.85  79.100  118.90  34.490  175.00  41.400  343.9  15.280
# 2022-04-06  46.50  76.300  114.40  33.990  172.70  39.900  331.3  15.200
# 2022-04-07  46.00  77.000  114.15  33.500  171.00  40.190  345.4  14.840
# 2022-04-08  44.65  75.000  113.70  33.200  167.10  40.360  336.7  14.540
#
# [1300 rows x 8 columns]

# %%
mean_daily_ret = stocks.pct_change(1).mean()
mean_daily_ret
# Out:
# R22    0.001061
# PKN    0.000319
# PEO    0.000242
# PZU    0.000289
# KGH    0.000529
# PKO    0.000425
# DNP    0.002092
# TOR    0.000689
# dtype: float64

# %%
stocks.pct_change(1).corr()
# Out:
#           R22       PKN       PEO       PZU       KGH       PKO       DNP  \
# R22  1.000000  0.187547  0.203833  0.183967  0.221296  0.198192  0.170663
# PKN  0.187547  1.000000  0.405941  0.421068  0.387775  0.389061  0.144819
# PEO  0.203833  0.405941  1.000000  0.598411  0.363691  0.758202  0.155638
# PZU  0.183967  0.421068  0.598411  1.000000  0.399215  0.610253  0.182249
# KGH  0.221296  0.387775  0.363691  0.399215  1.000000  0.392633  0.199448
# PKO  0.198192  0.389061  0.758202  0.610253  0.392633  1.000000  0.169110
# DNP  0.170663  0.144819  0.155638  0.182249  0.199448  0.169110  1.000000
# TOR  0.157328  0.148665  0.238777  0.240236  0.229400  0.232267  0.118907
#
#           TOR
# R22  0.157328
# PKN  0.148665
# PEO  0.238777
# PZU  0.240236
# KGH  0.229400
# PKO  0.232267
# DNP  0.118907
# TOR  1.000000

# %%
stock_normed = stocks/stocks.iloc[0]
stock_normed.plot(kind='line',figsize=(16,8))

# %%
stock_daily_ret = stocks.pct_change(1)
log_ret = np.log(stocks/stocks.shift(1))
log_ret.hist(bins=100,figsize=(16,8))
plt.tight_layout()

# %%
log_ret.describe().transpose()
# Out:
#       count      mean       std       min       25%       50%       75%  \
# R22  1067.0  0.000668  0.028068 -0.199266 -0.014055  0.000000  0.014244
# PKN  1299.0  0.000050  0.023226 -0.151253 -0.012954  0.000412  0.013021
# PEO  1299.0  0.000028  0.020754 -0.176026 -0.009464  0.000000  0.010132
# PZU  1299.0  0.000136  0.017518 -0.104678 -0.008996  0.000000  0.010389
# KGH  1299.0  0.000246  0.023805 -0.129956 -0.012981  0.000508  0.013527
# PKO  1299.0  0.000221  0.020216 -0.112198 -0.011500  0.000415  0.011703
# DNP  1242.0  0.001797  0.024256 -0.139762 -0.011849  0.001025  0.014928
# TOR  1299.0  0.000246  0.029758 -0.228482 -0.014145  0.000000  0.013126
#
#           max
# R22  0.130224
# PKN  0.136764
# PEO  0.090381
# PZU  0.072596
# KGH  0.115675
# PKO  0.092667
# DNP  0.101448
# TOR  0.204551

# %%
log_ret.mean() * 252
# Out:
# R22    0.168223
# PKN    0.012563
# PEO    0.006930
# PZU    0.034367
# KGH    0.062014
# PKO    0.055700
# DNP    0.452771
# TOR    0.062027
# dtype: float64

# %%
log_ret.cov()*252 # multiply by days
# Out:
#           R22       PKN       PEO       PZU       KGH       PKO       DNP  \
# R22  0.198534  0.033035  0.032846  0.024525  0.039999  0.030303  0.030662
# PKN  0.033035  0.135940  0.049721  0.043377  0.054867  0.046310  0.021457
# PEO  0.032846  0.049721  0.108542  0.055147  0.045574  0.080314  0.021026
# PZU  0.024525  0.043377  0.055147  0.077337  0.042281  0.054711  0.019963
# KGH  0.039999  0.054867  0.045574  0.042281  0.142797  0.047924  0.029775
# PKO  0.030303  0.046310  0.080314  0.054711  0.047924  0.102989  0.021637
# DNP  0.030662  0.021457  0.021026  0.019963  0.029775  0.021637  0.148265
# TOR  0.036424  0.027249  0.038529  0.032683  0.042203  0.036085  0.022608
#
#           TOR
# R22  0.036424
# PKN  0.027249
# PEO  0.038529
# PZU  0.032683
# KGH  0.042203
# PKO  0.036085
# DNP  0.022608
# TOR  0.223155

# %%
# Out:
# 8

# %%
# Set seed (optional)
np.random.seed(101)

# Stock Columns
print('Stocks')
print(stocks.columns)
print('\n')

# Create Random Weights
print('Creating Random Weights')
weights = np.array(np.random.random(len(np.sum(log_ret.cov()))))
print(weights)
print('\n')

# Rebalance Weights
print('Rebalance to sum to 1.0')
weights = weights / np.sum(weights)
print(weights)
print('\n')

# Expected Return
print('Expected Portfolio Return')
exp_ret = np.sum(log_ret.mean() * weights) *252
print(exp_ret)
print('\n')

# Expected Variance
print('Expected Volatility')
exp_vol = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))
print(exp_vol)
print('\n')

# Sharpe Ratio
SR = exp_ret/exp_vol
print('Sharpe Ratio')
print(SR)
# Out:
# Stocks
# Index(['R22', 'PKN', 'PEO', 'PZU', 'KGH', 'PKO', 'DNP', 'TOR'], dtype='object')
#
#
# Creating Random Weights
# [0.51639863 0.57066759 0.02847423 0.17152166 0.68527698 0.83389686
#  0.30696622 0.89361308]
#
#
# Rebalance to sum to 1.0
# [0.12888007 0.14242423 0.00710645 0.04280748 0.17102785 0.20811962
#  0.07661102 0.22302328]
#
#
# Expected Portfolio Return
# 0.09570938341480233
#
#
# Expected Volatility
# 0.2403926327940112
#
#
# Sharpe Ratio
# 0.3981377561466879

# %%
num_ports = 15000

all_weights = np.zeros((num_ports,len(stocks.columns)))
ret_arr = np.zeros(num_ports)
vol_arr = np.zeros(num_ports)
sharpe_arr = np.zeros(num_ports)

for ind in range(num_ports):

    # Create Random Weights
    weights = np.array(np.random.random(len(np.sum(log_ret.cov()))))

    # Rebalance Weights
    weights = weights / np.sum(weights)
    
    # Save Weights
    all_weights[ind,:] = weights

    # Expected Return
    ret_arr[ind] = np.sum((log_ret.mean() * weights) *252)

    # Expected Variance
    vol_arr[ind] = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))

    # Sharpe Ratio
    sharpe_arr[ind] = ret_arr[ind]/vol_arr[ind]

# %%
print('Sharpe Ratio: ')
sharpe_arr.max()
# Out:
# Sharpe Ratio:
# 0.9772305126909663

# %%
sharpe_arr.argmax()
# Out:
# 2984

# %%
print('Weights of Portfolio: ')
max_sr_ret = ret_arr[sharpe_arr.argmax()]
max_sr_vol = vol_arr[sharpe_arr.argmax()]
all_weights[1419,:]
# Out:
# Weights of Portfolio:
# array([0.27522946, 0.01925079, 0.10539016, 0.03971925, 0.27288238,
#        0.03728338, 0.13908494, 0.11115964])

# %%
print('Portfolio Return')
print(max_sr_ret)
print('\n')
print('Portfolio Voliatility')
print(max_sr_vol)
# Out:
# Portfolio Return
# 0.2388457013323764
#
#
# Portfolio Voliatility
# 0.24441081017279653

# %%
plt.figure(figsize=(12,8))
plt.scatter(vol_arr,ret_arr,c=sharpe_arr,cmap='plasma')
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')

# Add red dot for max SR
plt.scatter(max_sr_vol,max_sr_ret,c='red',s=50,edgecolors='black')

# %%
log_ret.cov()
# Out:
#           R22       PKN       PEO       PZU       KGH       PKO       DNP  \
# R22  0.000788  0.000131  0.000130  0.000097  0.000159  0.000120  0.000122
# PKN  0.000131  0.000539  0.000197  0.000172  0.000218  0.000184  0.000085
# PEO  0.000130  0.000197  0.000431  0.000219  0.000181  0.000319  0.000083
# PZU  0.000097  0.000172  0.000219  0.000307  0.000168  0.000217  0.000079
# KGH  0.000159  0.000218  0.000181  0.000168  0.000567  0.000190  0.000118
# PKO  0.000120  0.000184  0.000319  0.000217  0.000190  0.000409  0.000086
# DNP  0.000122  0.000085  0.000083  0.000079  0.000118  0.000086  0.000588
# TOR  0.000145  0.000108  0.000153  0.000130  0.000167  0.000143  0.000090
#
#           TOR
# R22  0.000145
# PKN  0.000108
# PEO  0.000153
# PZU  0.000130
# KGH  0.000167
# PKO  0.000143
# DNP  0.000090
# TOR  0.000886

# %%
all_weights[1419,:]
# Out:
# array([0.27522946, 0.01925079, 0.10539016, 0.03971925, 0.27288238,
#        0.03728338, 0.13908494, 0.11115964])

# %%
for stock_df in (R22_end,PKN_end,PEO_end, PZU_end, KGH_end, PKO_end, DNP_end, TOR_end):
    stock_df['Normed Return'] = stock_df['Open']/stock_df.iloc[0]['Open']
    
for stock_df,allo in zip([R22_end,PKN_end,PEO_end, PZU_end, KGH_end, PKO_end, DNP_end, TOR_end],[.27,.02,.1,.04,0.27,0.2,0.04,0.14,0.12]):
    stock_df['Allocation'] = stock_df['Normed Return']*allo
    
for stock_df in (R22_end,PKN_end,PEO_end, PZU_end, KGH_end, PKO_end, DNP_end, TOR_end):
    stock_df['Position Values'] = stock_df['Allocation']*20000
    
portfolio_val = pd.concat([R22_end['Position Values'],PKN_end['Position Values'],PEO_end['Position Values'],PZU_end['Position Values'],KGH_end['Position Values'],PKO_end['Position Values'],DNP_end['Position Values'],TOR_end['Position Values']],axis=1)

portfolio_val.columns = ['R22','PKN','PEO','PZU','KGH','PKO', 'DNP', 'TOR']

portfolio_val['Total'] = portfolio_val.sum(axis=1)

portfolio_val.head()
# Out:
# C:\Users\48503\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\48503\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\48503\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             R22         PKN          PEO         PZU          KGH  \
# Date
# 2017-01-26  NaN  400.000000  2000.000000  800.000000  5400.000000
# 2017-01-27  NaN  392.807659  1971.196792  791.283711  5290.558576
# 2017-01-30  NaN  401.678592  1990.702762  791.053578  5465.842808
# 2017-01-31  NaN  393.735152  1949.503236  784.350953  5347.503707
# 2017-02-01  NaN  395.129237  1963.904840  789.701546  5485.417696
#
#                     PKO  DNP          TOR         Total
# Date
# 2017-01-26  4000.000000  NaN  2800.000000  15400.000000
# 2017-01-27  3976.095354  NaN  2793.636966  15215.579058
# 2017-01-30  3918.116684  NaN  2774.812991  15342.207415
# 2017-01-31  3861.194572  NaN  2793.636966  15129.924586
# 2017-02-01  3909.135933  NaN  2871.849257  15415.138510

# %%
portfolio_val['Total'].plot(figsize=(10,8))
plt.title('Total Portfolio Value')
# Out:
# Text(0.5, 1.0, 'Total Portfolio Value')

# %%
portfolio_val.drop('Total',axis=1).plot(kind='line', figsize = (16,8))
